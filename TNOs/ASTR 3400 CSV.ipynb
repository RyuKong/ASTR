# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
# %matplotlib notebook

# %%
def Main():
    np.seterr(divide='ignore', invalid='ignore')
    FitsDirc = '/home/jiko1138/Kong_fits_lc_pymovie/04VV130-RECON'
    FitsData = pandas.read_csv(FitsDirc + '8.csv', skiprows=41, sep=',')
    FitsRows = np.array(FitsData.loc[:])
    frmnum,times = FitsRows[:,0],FitsRows[:,1]
    tar  = FitsRows[:,2]
    anc1 = FitsRows[:,3]
    anc2 = FitsRows[:,4]
    anc3 = FitsRows[:,5]
    anc4 = FitsRows[:,6]
    norm = (tar/anc1)
    nor2 = (tar/anc2)
    #plt.plot(frmnum,tar)
    #plt.plot(frmnum,anc1)
    #plt.plot(frmnum,anc2)
    print(times[530])
    plt.figure(figsize=(16,6)) 
    plt.rc('xtick',labelsize=10)
    plt.scatter(frmnum,norm,label='Target/Anchor1',s=28)
    plt.scatter(frmnum,nor2,label='Target/Anchor2',s=28)
    plt.legend(loc='upper right',prop={'size':10})
    plt.ylabel('Normalized Stellar Flux')
    plt.savefig('Beatty.png')
            
        
        

    #plt.ylim(0,1.5)

if __name__ == '__main__':
    Main()
# Out:
# [04:57:55.7488505]
# <img src="data:image/png;base64,..." width="1600">

# %%
def Main():
    np.seterr(divide='ignore', invalid='ignore')
    FitsDirc = '/home/jiko1138/Kong_fits_lc_pymovie/04VV130-RECON'
    FitsData = pandas.read_csv(FitsDirc + '6.csv', skiprows=74, sep=',')
    FitsRows = np.array(FitsData.loc[:])
    frmnum,times = FitsRows[:,0],FitsRows[:,1]
    tar  = FitsRows[:,2]
    anc1 = FitsRows[:,3]
    anc2 = FitsRows[:,4]
    anc3 = FitsRows[:,5]
    anc4 = FitsRows[:,6]
    norm = (tar/anc1)
    nor2 = (tar/anc2)
    #plt.plot(frmnum,tar)
    #plt.plot(frmnum,anc1)
    #plt.plot(frmnum,anc2)
    print(times[340])
    plt.figure(figsize=(16,6)) 
    plt.rc('xtick',labelsize=10)
    plt.scatter(frmnum,norm,label='Target/Anchor1',s=28)
    plt.scatter(frmnum,nor2,label='Target/Anchor2',s=28)
    plt.legend(loc='upper right',prop={'size':10})
    plt.ylabel('Normalized Stellar Flux')
    plt.savefig('Beatty1.png')
            
        
        

    #plt.ylim(0,1.5)

if __name__ == '__main__':
    Main()
# Out:
# [04:59:10.3252941]
# <img src="data:image/png;base64,..." width="1600">
